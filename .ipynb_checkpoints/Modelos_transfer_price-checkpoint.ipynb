# %% [markdown]
# # Modelos de regresion aplicando:
# + Regresion lineal
# + Ridge
# + ElasticNet
# + GBR

# %%
# lectura de archivo y filtros o trasnformaciones
import numpy as np
import pandas as pd

# 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.linear_model import ElasticNet, LinearRegression,Ridge
from sklearn.metrics import (explained_variance_score,
                             mean_absolute_error,
                             mean_squared_error,
                             mean_squared_log_error,
                             median_absolute_error,
                             r2_score)


# visualizacion de datos
import seaborn as sns 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
font = {'family' : 'sans',
        'weight' : 'bold',
        'size'   : 20}
plt.rc('font', **font)
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams[u'figure.figsize'] = (16,8)

# %%
df = pd.read_pickle('df_4_regresion_clean.pkl').reset_index(drop=True)

# %%
df.head()
# Out:
#            jugador fecha_nacimiento_x nacionalidad  \
# 0     Abila, Ramon         1989-10-14    Argentina
# 1  Acevedo, Nelson         1988-07-11    Argentina
# 2     Acosta, Joel         1991-01-16    Argentina
# 3  Acosta, Lautaro         1988-03-14    Argentina
# 4    Acuna, Marcos         1991-10-28    Argentina
#
#                          equipo_x             posicion_1  \
# 0           Club Atlético Huracán              Delantero
# 1  Club Atlético Unión (Santa Fe)      Volante defensivo
# 2         Club Atlético Patronato              Delantero
# 3             Club Atlético Lanús  Volante por izquierda
# 4                     Racing Club    Volante por derecha
#
#                 posicion_2 posicion_3  minutos_jugados_pos1  \
# 0  Delantero con Movilidad  No aplica                2094.0
# 1           Volante Mixto   No aplica                 699.0
# 2  Delantero con Movilidad  No aplica                1539.0
# 3           Volante Mixto   No aplica                1842.0
# ...

# %%
cols_cat = ['nacionalidad','equipo_x','posicion_1','posicion_2','posicion_3']

# %%
# se generan dos dataframes una quitando una variable dummi de cada categoria.
df_dummi_first_drop = pd.get_dummies(df,columns=cols_cat,drop_first=True)
# df para GBR
df_dummi = pd.get_dummies(df,columns=cols_cat,drop_first=False)

# %%
df_dummi.shape,df_dummi_first_drop.shape
# Out:
# ((653, 76), (653, 71))

# %%
x_reg = ['minutos_jugados_pos1','minutos_jugados_pos2', 'minutos_jugados_pos3','minutos_totales',
    'ranking_pos1','ranking_pos2', 'ranking_pos3', 'ranking_promedio',
    'ranking_restringido_pos1','ranking_restringido_pos2', 'ranking_restringido_pos3','ranking_restringido_promedio',
    'value_2015', 
    'edad', 
    'nacionalidad_Chilena','nacionalidad_Colombiana', 'nacionalidad_Ecuatoriana','nacionalidad_Paraguaya', 'nacionalidad_Uruguaya',
    'equipo_x_Asociación Atlética Argentinos Juniors','equipo_x_Atlético de Rafaela', 'equipo_x_Club Atlético Aldosivi',
    'equipo_x_Club Atlético Banfield', 'equipo_x_Club Atlético Belgrano','equipo_x_Club Atlético Boca Juniors', 'equipo_x_Club Atlético Colón',
    'equipo_x_Club Atlético Huracán','equipo_x_Club Atlético Independiente', 'equipo_x_Club Atlético Lanús',
    "equipo_x_Club Atlético Newell's Old Boys",'equipo_x_Club Atlético Patronato',
    'equipo_x_Club Atlético River Plate','equipo_x_Club Atlético Rosario Central',
    'equipo_x_Club Atlético San Lorenzo de Almagro','equipo_x_Club Atlético San Martín (SJ)',
    'equipo_x_Club Atlético Sarmiento (Junin)','equipo_x_Club Atlético Temperley', 'equipo_x_Club Atlético Tigre',
    'equipo_x_Club Atlético Tucumán','equipo_x_Club Atlético Unión (Santa Fe)',
    'equipo_x_Club Atlético Vélez Sarsfield','equipo_x_Club Deportivo Godoy Cruz Antonio Tomba',
    'equipo_x_Club Estudiantes de La Plata', 'equipo_x_Club Olimpo','equipo_x_Club de Gimnasia y Esgrima La Plata',
    'equipo_x_Defensa y Justicia', 'equipo_x_Quilmes Atlético Club','equipo_x_Racing Club', 
    'posicion_1_Delantero','posicion_1_Lateral por derecha', 'posicion_1_Lateral por izquierda','posicion_1_Volante Mixto ', 'posicion_1_Volante defensivo',
    'posicion_1_Volante por derecha', 'posicion_1_Volante por izquierda',
    'posicion_2_Delantero', 'posicion_2_Delantero con Movilidad','posicion_2_Lateral por derecha', 'posicion_2_Lateral por izquierda',
    'posicion_2_No aplica', 'posicion_2_Volante Mixto ','posicion_2_Volante defensivo', 'posicion_2_Volante ofensivo','posicion_2_Volante por derecha', 
    'posicion_3_No aplica','posicion_3_Volante Mixto ', 'posicion_3_Volante ofensivo']
y = 'value_2016'

# %% [markdown]
# # Para generar las regresiones se tiene que estandarizar los valores

# %% [markdown]
# # PROBABLE QUITAR OUTLIERS

# %%
mean = df_dummi_first_drop[x_reg + [y]].mean()
std = df_dummi_first_drop[x_reg + [y]].std()
df_reg_std = (df_dummi_first_drop[x_reg + [y]] - mean)/std

# %%
x_gbr = ['minutos_jugados_pos1','minutos_jugados_pos2', 'minutos_jugados_pos3', 
         'ranking_pos1','ranking_pos2', 'ranking_pos3', 'ranking_restringido_pos1',
       'ranking_restringido_pos2', 'ranking_restringido_pos3', 'value_2015',
       'edad', 'minutos_totales', 'ranking_promedio',
       'ranking_restringido_promedio', 'nacionalidad_Argentina',
       'nacionalidad_Chilena', 'nacionalidad_Colombiana',
       'nacionalidad_Ecuatoriana', 'nacionalidad_Paraguaya',
       'nacionalidad_Uruguaya', 'equipo_x_Arsenal Fútbol Club',
       'equipo_x_Asociación Atlética Argentinos Juniors',
       'equipo_x_Atlético de Rafaela', 'equipo_x_Club Atlético Aldosivi',
       'equipo_x_Club Atlético Banfield', 'equipo_x_Club Atlético Belgrano',
       'equipo_x_Club Atlético Boca Juniors', 'equipo_x_Club Atlético Colón',
       'equipo_x_Club Atlético Huracán',
       'equipo_x_Club Atlético Independiente', 'equipo_x_Club Atlético Lanús',
       "equipo_x_Club Atlético Newell's Old Boys",
       'equipo_x_Club Atlético Patronato',
       'equipo_x_Club Atlético River Plate',
       'equipo_x_Club Atlético Rosario Central',
       'equipo_x_Club Atlético San Lorenzo de Almagro',
       'equipo_x_Club Atlético San Martín (SJ)',
       'equipo_x_Club Atlético Sarmiento (Junin)',
       'equipo_x_Club Atlético Temperley', 'equipo_x_Club Atlético Tigre',
       'equipo_x_Club Atlético Tucumán',
       'equipo_x_Club Atlético Unión (Santa Fe)',
       'equipo_x_Club Atlético Vélez Sarsfield',
       'equipo_x_Club Deportivo Godoy Cruz Antonio Tomba',
       'equipo_x_Club Estudiantes de La Plata', 'equipo_x_Club Olimpo',
       'equipo_x_Club de Gimnasia y Esgrima La Plata',
       'equipo_x_Defensa y Justicia', 'equipo_x_Quilmes Atlético Club',
       'equipo_x_Racing Club', 'posicion_1_Defensa central',
       'posicion_1_Delantero', 'posicion_1_Lateral por derecha',
       'posicion_1_Lateral por izquierda', 'posicion_1_Volante Mixto ',
       'posicion_1_Volante defensivo', 'posicion_1_Volante por derecha',
       'posicion_1_Volante por izquierda', 'posicion_2_Defensa central',
       'posicion_2_Delantero', 'posicion_2_Delantero con Movilidad',
       'posicion_2_Lateral por derecha', 'posicion_2_Lateral por izquierda',
       'posicion_2_No aplica', 'posicion_2_Volante Mixto ',
       'posicion_2_Volante defensivo', 'posicion_2_Volante ofensivo',
       'posicion_2_Volante por derecha', 'posicion_3_Delantero con Movilidad',
       'posicion_3_No aplica', 'posicion_3_Volante Mixto ',
       'posicion_3_Volante ofensivo']
y = 'value_2016'

# %%
x_train_test,x_valid, y_train_test,y_valid = train_test_split(
    df_reg_std[x_reg], df_reg_std[y], test_size=0.1, random_state = 8)

x_train,x_test, y_train,y_test = train_test_split(
    x_train_test, y_train_test, test_size=0.1, random_state = 8)

# %%
linear_reg = LinearRegression().fit(x_train, y_train)

# %%
coef = pd.Series(linear_reg.coef_, index = x_train.columns).sort_values()
imp_coef = pd.concat([coef.head(10), coef.tail(10)])
imp_coef.plot(kind = "barh", color='r',alpha=0.8)
plt.title("Coeficientes del modelo");

# %% [markdown]
# _CLARAMENTE HAY QUE PENALIZAR LAS VARIABLES_

# %%
ridge_reg = Ridge().fit(x_train, y_train)

# %%
coef = pd.Series(ridge_reg.coef_, index = x_train.columns).sort_values()
imp_coef = pd.concat([coef.head(5), coef.tail(5)])
imp_coef.plot(kind = "barh", color='r',alpha=0.8)
plt.title("Coeficientes del modelo");

# %% [markdown]
# # SIGUE DANDO RARO LOS RANKINGS 1 y 2 LO DEMAS LO VEO BIEN

# %%
y_pred = ridge_reg.predict(x_test)

print('RMSE',np.sqrt(mean_squared_error(y_test,y_pred)))
res = (y_test - y_pred)/y_test
plt.hist(res,bins=100)
print('valor promedio test',y_test.mean())
print('residuo',res.mean()*100)
print('r_2',r2_score(y_test,y_pred));
# Out:
# RMSE 0.60964142149416
# valor promedio test -0.006100010419280427
# residuo 140.82660027397077
# r_2 0.413186681688247

# %%
# tamanio de lambda
grid_lambda = np.linspace(0.0000001, 200, 500)
NT = len(grid_lambda)
#matriz para guardar resultado de ecm
mse_error = np.zeros((NT))

for j,alpha in enumerate(grid_lambda):
    ridge_reg = Ridge(alpha=alpha)

# hacer unestimación sobre train
    ridge_reg.fit(x_train, y_train)
# hagamos un predict: tst
    rmse_test = np.sqrt(mean_squared_error(y_test, ridge_reg.predict(x_test)))
# y guardemos
    mse_error[j] = rmse_test
#     print("iteracion:",j+1,"valor de alpha:", alpha,"error:", rmse_test)

# %%
pd.DataFrame(mse_error,index=grid_lambda).plot(legend=False)

# %%
min_value_lambda = pd.DataFrame(mse_error,index=grid_lambda).idxmin()[0]

# %%
ridge_reg = Ridge(alpha=min_value_lambda).fit(x_train, y_train)

# %%
coef = pd.Series(ridge_reg.coef_, index = x_train.columns).sort_values()
imp_coef = pd.concat([coef.head(5), coef.tail(5)])
imp_coef.plot(kind = "barh", color='r',alpha=0.8)
plt.title("Coeficientes del modelo");

# %% [markdown]
# # SIGUE DANDO RARO

# %%
y_pred = ridge_reg.predict(x_test)

print('RMSE',np.sqrt(mean_squared_error(y_test,y_pred)))
res = (y_test - y_pred)/y_test
plt.hist(res,bins=100)
print('valor promedio test',y_test.mean())
print('residuo',res.mean()*100)
print('r_2',r2_score(y_test,y_pred));
# Out:
# RMSE 0.6025537628460744
# valor promedio test -0.006100010419280427
# residuo 139.26404858646708
# r_2 0.4267518871297252

# %%
plt.plot(y_test,y_pred,'.')
plt.plot((-1,3),(-1,3), '--')

# %%
#Tamaño grid depth
ND = 6
min_depth = 1
max_depth = 6
grid_depth =  np.linspace(min_depth,max_depth,ND).astype('int')
# tamaño grid ntrees
NT = 20
min_trees = 1
max_trees = 100
grid_tree = np.linspace(min_trees, max_trees, NT).astype('int')

mse_error = np.zeros((ND,NT))

for i, max_depth in enumerate(grid_depth):
    for j,ntrees in enumerate(grid_tree):
        clf = GradientBoostingRegressor(n_estimators= ntrees, 
                                        max_depth = max_depth,random_state=8)

# hacer unestimación sobre train
        clf.fit(x_train, y_train)
    # hagamos un predict: tst
        rmse_test = np.sqrt(mean_squared_error(y_test, clf.predict(x_test)))
    # y guardemos
        mse_error[i,j] = rmse_test
#         print("iteracion:",j+1,"numero de arboles:", ntrees,"error:", rmse_test)

# %%
df_error = pd.DataFrame(
    mse_error,columns=grid_tree,index=grid_depth)
plt.figure(figsize=(15,7))
sns.heatmap(df_error,
            annot=True,fmt='.3f')

# %%
gs_gbc = GradientBoostingRegressor(n_estimators= 27, max_depth = 4,random_state=8)
# hacer unestimación sobre train
gs_gbc.fit(x_train, y_train)


y_pred = gs_gbc.predict(x_test)

print('RMSE',np.sqrt(mean_squared_error(y_test,y_pred)))
res = (y_test - y_pred)/y_test
plt.hist(res,bins=100)
print('valor promedio test',y_test.mean())
print('residuo',res.mean()*100)
print('r_2',r2_score(y_test,y_pred));
# Out:
# RMSE 0.699149049424013
# valor promedio test 0.8906779661016949
# residuo -88.60739998806585
# r_2 0.4473673725314652

# %%
y_valid_model_gbm = gs_gbc.predict(x_valid)

# %%
print('RMSE',np.sqrt(mean_squared_error(y_valid,y_valid_model_gbm)))
res = (y_valid - y_valid_model_gbm)/y_valid
plt.hist(res,bins=100)
print('valor promedio test',y_valid.mean())
print('residuo',res.mean()*100)
print('r_2',r2_score(y_valid,y_valid_model_gbm));
# Out:
# RMSE 0.7673821813792662
# valor promedio test 0.6279545454545454
# residuo -179.83442151502587
# r_2 -0.6550461220118511

# %% [markdown]
# # Interpretacion variables

# %%
#DF de variables mas importantes
f_imp = pd.DataFrame(gs_gbc.feature_importances_,
                     index=x_train.columns, columns=['imp'])
#calculo de importancia relativa
f_imp['imp_rel'] = (f_imp/f_imp.max()*100)
#plot de importancia de variables
f_imp[f_imp.imp_rel > 0.5].sort_values('imp_rel',ascending=True).imp_rel.plot.barh(figsize=(6,7),
                                                              title='Importancia de Variables',color='magenta')
plt.xlabel('Importancia relativa')
# Out:
# Text(0.5, 0, 'Importancia relativa')

# %%
df[df.equipo_x == 'Club Atlético River Plate'][['jugador','value_2015','value_2016','cociente']]
# Out:
#                     jugador  value_2015  value_2016    cociente
# 14            Alario, Lucas        0.05        5.50  110.000000
# 37          Arzura, Joaquin        0.45        2.60    5.777778
# 66         Bertolo, Nicolas        1.80        0.80    0.444444
# 87              Boye, Lucas        0.50        0.50    1.000000
# 123           Casco, Milton        1.30        3.20    2.461538
# 187        Domingo, Nicolas        0.75        0.75    1.000000
# 191      Driussi, Sebastian        0.50        6.00   12.000000
# 215      Fernandez, Ignacio        0.50        3.20    6.400000
# 251      Funes Mori, Ramiro        4.00        4.00    1.000000
# 317       Larrondo, Marcelo        0.60        1.75    2.916667
# 338    Lopez, Franco Alexis        0.05        0.25    5.000000
# 352        Mammana, Emanuel        0.25        0.25    1.000000
# 365       Martinez, Gonzalo        0.05        9.00  180.000000
# 377          Mayada, Camilo        1.25        2.40    1.920000
# ...
